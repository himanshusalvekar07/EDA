# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
##series is 1-dimensional

# %%
series=pd.Series(["Mercedes","BMW","Skoda"])
series
# Out:
# 0    Mercedes
# 1         BMW
# 2       Skoda
# dtype: object

# %%
colour=pd.Series(["Black","Blue","Metallic-grey"])
colour
# Out:
# 0            Black
# 1             Blue
# 2    Metallic-grey
# dtype: object

# %%
car_data=pd.DataFrame({"Car make":series,"Colour":colour})
car_data
# Out:
#    Car make         Colour
# 0  Mercedes          Black
# 1       BMW           Blue
# 2     Skoda  Metallic-grey

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_prices=pd.Series([3000000,3200000,5550000,12000000])
car_prices
# Out:
# 0     3000000
# 1     3200000
# 2     5550000
# 3    12000000
# dtype: int64

# %%
car_prices.mean()
# Out:
# 5937500.0

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.loc[9]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)        31600
# Doors                    4
# Price            $9,700.00
# Name: 9, dtype: object

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped=car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# Column from Series
seats_column=pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"]=seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    5.0
# 6   honda   Blue          45698      4   $7,500.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8  toyota  White          60000      4   $6,250.00    5.0
# 9  nissan  White          31600      4   $9,700.00    5.0

# %%
#Column from Python List
fuel_economy=[7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5]
car_sales["Fuel per 100km"]=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5

# %%
car_sales[car_sales["Fuel per 100km"]<5.5]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100km
# 2  toyota   Blue          32549      3  $7,000.00    5.0             5.0
# 5  toyota  Green          99213      4  $4,500.00    5.0             4.7
# 8  toyota  White          60000      4  $6,250.00    5.0             3.0
# 9  nissan  White          31600      4  $9,700.00    5.0             4.5

# %%
car_sales["Total fuel Used in (L)"]=car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100km"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)
# 0               11253.225
# 1                8086.708
# 2                1627.450
# 3                1073.184
# ...

# %%
# Creating columns from a single value 
car_sales["Number Of wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels
# 0               11253.225                 4
# 1                8086.708                 4
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels
# 0               11253.225                 4
# 1                8086.708                 4
# ...

# %%
car_sales["Passed Road Safety"]=True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                       object
# Colour                     object
# Odometer (KM)             float64
# Doors                       int64
# Seats                     float64
# Fuel per 100km            float64
# Total fuel Used in (L)    float64
# Number Of wheels            int64
# Passed Road Safety           bool
# Price                       int64
# dtype: object

# %%
car_sales[car_sales["Fuel per 100km"]<6]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100km  \
# 2  toyota   Blue          32549      3  $7,000.00    5.0             5.0
# 5  toyota  Green          99213      4  $4,500.00    5.0             4.7
# 8  toyota  White          60000      4  $6,250.00    5.0             3.0
# 9  nissan  White          31600      4  $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 2                1627.450                 4                True
# 5                4663.011                 4                True
# 8                1800.000                 4                True
# 9                1422.000                 4                True

# %%
car_sales_shuffled=car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 7   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 9  nissan  White          31600      4   $9,700.00    5.0             4.5
# 0  toyota  White         150043      4   $4,000.00    5.0             7.5
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 5  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 6   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 1   honda    Red          87899      4   $5,000.00    5.0             9.2
# 2  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 4  nissan  White         213095      4   $3,500.00    5.0             8.7
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 7                4762.206                 4                True
# ...

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0   honda   Blue          54738      4   $7,000.00    5.0             8.7
# 1  nissan  White          31600      4   $9,700.00    5.0             4.5
# 2  toyota  White         150043      4   $4,000.00    5.0             7.5
# 3     bmw  Black          11179      5  $22,000.00    5.0             9.6
# 4  toyota  Green          99213      4   $4,500.00    5.0             4.7
# 5   honda   Blue          45698      4   $7,500.00    5.0             7.6
# 6   honda    Red          87899      4   $5,000.00    5.0             9.2
# 7  toyota   Blue          32549      3   $7,000.00    5.0             5.0
# 8  toyota  White          60000      4   $6,250.00    5.0             3.0
# 9  nissan  White         213095      4   $3,500.00    5.0             8.7
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0                4762.206                 4                True
# ...

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x : x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             7.5
# 1   honda    Red      54936.875      4   $5,000.00    5.0             9.2
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             5.0
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             9.6
# 4  nissan  White     133184.375      4   $3,500.00    5.0             8.7
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             4.7
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             7.6
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             8.7
# 8  toyota  White      37500.000      4   $6,250.00    5.0             3.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# ...

# %%
car_sales=car_sales.drop("Price",axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
# 5  toyota  Green      62008.125      4    5.0             4.7
# 6   honda   Blue      28561.250      4    5.0             7.6
# 7   honda   Blue      34211.250      4    5.0             8.7
# 8  toyota  White      37500.000      4    5.0             3.0
# 9  nissan  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety
# 0               11253.225                 4                True
# 1                8086.708                 4                True
# 2                1627.450                 4                True
# ...

# %%
car_sales["Price"]=[4000,5000,7000,22000,3500,4500,7500,7000,6250,9700]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
# 5  toyota  Green      62008.125      4    5.0             4.7
# 6   honda   Blue      28561.250      4    5.0             7.6
# 7   honda   Blue      34211.250      4    5.0             8.7
# 8  toyota  White      37500.000      4    5.0             3.0
# 9  nissan  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# ...

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors  Seats  Fuel per 100km  Total fuel Used in (L)  \
# Make
# bmw       6986.875000   5.00    5.0            9.60               1073.1840
# honda    39236.458333   4.00    5.0            8.50               5440.6540
# nissan   76467.187500   4.00    5.0            6.60               9980.6325
# toyota   53407.031250   3.75    5.0            5.05               4835.9215
#
#         Number Of wheels  Passed Road Safety    Price
# Make
# bmw                  4.0                 1.0  22000.0
# honda                4.0                 1.0   6500.0
# nissan               4.0                 1.0   6600.0
# toyota               4.0                 1.0   5437.5

# %% [markdown]
# ## Pandas  Revision

# %%
car_sales.dtypes
# Out:
# Make                       object
# Colour                     object
# Odometer (KM)             float64
# Doors                       int64
# Seats                     float64
# Fuel per 100km            float64
# Total fuel Used in (L)    float64
# Number Of wheels            int64
# Passed Road Safety           bool
# Price                       int64
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Seats', 'Fuel per 100km',
#        'Total fuel Used in (L)', 'Number Of wheels', 'Passed Road Safety',
#        'Price'],
#       dtype='object')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors  Seats  Fuel per 100km  \
# count      10.000000  10.000000   10.0       10.000000
# mean    49125.875000   4.000000    5.0        6.850000
# std     38739.669834   0.471405    0.0        2.340584
# min      6986.875000   3.000000    5.0        3.000000
# 25%     22397.656250   4.000000    5.0        4.775000
# 50%     35855.625000   4.000000    5.0        7.550000
# 75%     60240.312500   4.000000    5.0        8.700000
# max    133184.375000   5.000000    5.0        9.600000
#
#        Total fuel Used in (L)  Number Of wheels         Price
# count               10.000000              10.0     10.000000
# mean              5670.009700               4.0   7645.000000
# std               5575.650508               0.0   5379.407753
# min               1073.184000               4.0   3500.000000
# 25%               1670.587500               4.0   4625.000000
# 50%               4068.029500               4.0   6625.000000
# ...

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Make                    10 non-null     object
#  1   Colour                  10 non-null     object
#  2   Odometer (KM)           10 non-null     float64
#  3   Doors                   10 non-null     int64
#  4   Seats                   10 non-null     float64
#  5   Fuel per 100km          10 non-null     float64
#  6   Total fuel Used in (L)  10 non-null     float64
#  7   Number Of wheels        10 non-null     int64
#  8   Passed Road Safety      10 non-null     bool
#  9   Price                   10 non-null     int64
# dtypes: bool(1), float64(4), int64(3), object(2)
# memory usage: 858.0+ bytes

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 49125.875

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# 2                1627.450                 4                True   7000
# 3                1073.184                 4                True  22000
# 4               18539.265                 4                True   3500

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
# 5  toyota  Green      62008.125      4    5.0             4.7
# 6   honda   Blue      28561.250      4    5.0             7.6
# 7   honda   Blue      34211.250      4    5.0             8.7
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# 2                1627.450                 4                True   7000
# 3                1073.184                 4                True  22000
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
# 5  toyota  Green      62008.125      4    5.0             4.7
# 6   honda   Blue      28561.250      4    5.0             7.6
# 7   honda   Blue      34211.250      4    5.0             8.7
# 8  toyota  White      37500.000      4    5.0             3.0
# 9  nissan  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# ...

# %%
car_sales.loc[3]
# Out:
# Make                           bmw
# Colour                       Black
# Odometer (KM)             6986.875
# Doors                            5
# Seats                          5.0
# Fuel per 100km                 9.6
# Total fuel Used in (L)    1073.184
# Number Of wheels                 4
# Passed Road Safety            True
# Price                        22000
# Name: 3, dtype: object

# %%
car_sales.iloc[0]
# Out:
# Make                         toyota
# Colour                        White
# Odometer (KM)             93776.875
# Doors                             4
# Seats                           5.0
# Fuel per 100km                  7.5
# Total fuel Used in (L)    11253.225
# Number Of wheels                  4
# Passed Road Safety             True
# Price                          4000
# Name: 0, dtype: object

# %%
car_sales.iloc[0:2]
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000

# %%
car_sales.loc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# 2                1627.450                 4                True   7000
# 3                1073.184                 4                True  22000
# 4               18539.265                 4                True   3500

# %%
 car_sales["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 5  toyota  Green      62008.125      4    5.0             4.7
# 8  toyota  White      37500.000      4    5.0             3.0
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 2                1627.450                 4                True   7000
# 5                4663.011                 4                True   4500
# 8                1800.000                 4                True   6250

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 4  nissan  White     133184.375      4    5.0             8.7
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 4               18539.265                 4                True   3500

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# bmw     0  0  1
# honda   0  3  0
# nissan  0  2  0
# toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors  Seats  Fuel per 100km  Total fuel Used in (L)  \
# Make
# bmw       6986.875000   5.00    5.0            9.60               1073.1840
# honda    39236.458333   4.00    5.0            8.50               5440.6540
# nissan   76467.187500   4.00    5.0            6.60               9980.6325
# toyota   53407.031250   3.75    5.0            5.05               4835.9215
#
#         Number Of wheels  Passed Road Safety    Price
# Make
# bmw                  4.0                 1.0  22000.0
# honda                4.0                 1.0   6500.0
# nissan               4.0                 1.0   6600.0
# toyota               4.0                 1.0   5437.5

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 49125.875

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  toyota  White      93776.875      4    5.0             7.5
# 1   honda    Red      54936.875      4    5.0             9.2
# 2  toyota   Blue      20343.125      3    5.0             5.0
# 3     bmw  Black       6986.875      5    5.0             9.6
# 4  nissan  White     133184.375      4    5.0             8.7
# 5  toyota  Green      62008.125      4    5.0             4.7
# 6   honda   Blue      28561.250      4    5.0             7.6
# 7   honda   Blue      34211.250      4    5.0             8.7
# 8  toyota  White      37500.000      4    5.0             3.0
# 9  nissan  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# ...

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"]=car_sales["Make"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  TOYOTA  White      93776.875      4    5.0             7.5
# 1   HONDA    Red      54936.875      4    5.0             9.2
# 2  TOYOTA   Blue      20343.125      3    5.0             5.0
# 3     BMW  Black       6986.875      5    5.0             9.6
# 4  NISSAN  White     133184.375      4    5.0             8.7
# 5  TOYOTA  Green      62008.125      4    5.0             4.7
# 6   HONDA   Blue      28561.250      4    5.0             7.6
# 7   HONDA   Blue      34211.250      4    5.0             8.7
# 8  TOYOTA  White      37500.000      4    5.0             3.0
# 9  NISSAN  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# ...

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  TOYOTA  White      93776.875      4    5.0             7.5
# 1   HONDA    Red      54936.875      4    5.0             9.2
# 2  TOYOTA   Blue      20343.125      3    5.0             5.0
# 3     BMW  Black       6986.875      5    5.0             9.6
# 4  NISSAN  White     133184.375      4    5.0             8.7
# 5  TOYOTA  Green      62008.125      4    5.0             4.7
# 6   HONDA   Blue      28561.250      4    5.0             7.6
# 7   HONDA   Blue      34211.250      4    5.0             8.7
# 8  TOYOTA  White      37500.000      4    5.0             3.0
# 9  NISSAN  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Seats  Fuel per 100km  \
# 0  TOYOTA  White      93776.875      4    5.0             7.5
# 1   HONDA    Red      54936.875      4    5.0             9.2
# 2  TOYOTA   Blue      20343.125      3    5.0             5.0
# 3     BMW  Black       6986.875      5    5.0             9.6
# 4  NISSAN  White     133184.375      4    5.0             8.7
# 5  TOYOTA  Green      62008.125      4    5.0             4.7
# 6   HONDA   Blue      28561.250      4    5.0             7.6
# 7   HONDA   Blue      34211.250      4    5.0             8.7
# 8  TOYOTA  White      37500.000      4    5.0             3.0
# 9  NISSAN  White      19750.000      4    5.0             4.5
#
#    Total fuel Used in (L)  Number Of wheels  Passed Road Safety  Price
# 0               11253.225                 4                True   4000
# 1                8086.708                 4                True   5000
# ...
