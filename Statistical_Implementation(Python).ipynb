# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
import pandas as pd
data2=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics_With_Python/main/Iris.csv")

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data3=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics_With_Python/main/Titanic.csv")

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
import numpy as np

# %%
np.mean(data)
# Out:
# 37.36363636363637

# %%
np.median(data)
# Out:
# 32.0

# %%
np.median(data_copy)
# Out:
# 32.0

# %%
np.mean(data2['SepalLengthCm'])
# Out:
# 5.843333333333335

# %%
import statistics

# %%
statistics.mode(data)
# Out:
# 32

# %%
def Mean(d):
    l=len(d)
    Sum=0
    for i in d:
        Sum+=i
    return Sum/l

# %%
Mean(data)
# Out:
# 37.36363636363637

# %%
from scipy import stats as st
st.mode(data,keepdims=False)
# Out:
# ModeResult(mode=32, count=3)

# %%
data_copy.append(150)

# %%
data_copy2=data.copy()

# %%
data_copy2.append(75)

# %%
np.mean(data_copy2)
# Out:
# 40.5

# %%
np.mean(data_copy)
# Out:
# 46.75

# %%
np.median(data)
# Out:
# 32.0

# %%
np.median(data_copy)
# Out:
# 37.5

# %% [markdown]
# ## Incase of outliers always don't use mean ,use median!

# %%
np.median(data_copy2)
# Out:
# 37.5

# %%
np.percentile(data,50)
# Out:
# 32.0

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.percentile(data,(25,50,75,100))
# Out:
# array([28., 32., 45., 67.])

# %%
data_copy.append(150)

# %%
import seaborn as sns

# %% [markdown]
# ## Boxplot gives shows Lower Fc,25,50,75,100 and Outlier(IfPresent)

# %%
sns.boxplot(data=data_copy)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Outlier formulas!

# %%
q1,q2,q3,q4

IQR=q3-q1

lower_fence=q1-1.5*iqr
upper_fence=q3+1.5*iqr

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
np.var(data)
# Out:
# 226.23140495867773

# %%
np.std(data)
# Out:
# 15.040990823701666

# %%
np.random.choice(data)
# Out:
# 24

# %%
np.random.choice(data,size=3)
# Out:
# array([32, 32, 12])

# %%
data2.sample(n=15)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 97    98            6.2           2.9            4.3           1.3
# 120  121            6.9           3.2            5.7           2.3
# 112  113            6.8           3.0            5.5           2.1
# 40    41            5.0           3.5            1.3           0.3
# 0      1            5.1           3.5            1.4           0.2
# 66    67            5.6           3.0            4.5           1.5
# 104  105            6.5           3.0            5.8           2.2
# 75    76            6.6           3.0            4.4           1.4
# 137  138            6.4           3.1            5.5           1.8
# 16    17            5.4           3.9            1.3           0.4
# 105  106            7.6           3.0            6.6           2.1
# 82    83            5.8           2.7            3.9           1.2
# 124  125            6.7           3.3            5.7           2.1
# 19    20            5.1           3.8            1.5           0.3
# 29    30            4.7           3.2            1.6           0.2
#
#              Species
# 97   Iris-versicolor
# 120   Iris-virginica
# 112   Iris-virginica
# 40       Iris-setosa
# 0        Iris-setosa
# 66   Iris-versicolor
# 104   Iris-virginica
# 75   Iris-versicolor
# 137   Iris-virginica
# 16       Iris-setosa
# 105   Iris-virginica
# 82   Iris-versicolor
# 124   Iris-virginica
# 19       Iris-setosa
# 29       Iris-setosa

# %% [markdown]
# ## Variance-Function

# %%
def var(d):
    
    var=0
    l1=[]
    l=len(d)
    Sum=0
    for i in d:
        Sum=Sum+i
    mean=Sum/l
    
    for i in d:
        l1.append((mean-i)**2)
    
    s=sum(l1)
    var=s/(l-1)
    std=var**0.5
    
    print(f"Variance:{var} and Standard-Deviation:{std}")

# %%
var(data_copy)
# Out:
# Variance:1283.4772727272727 and Standard-Deviation:35.825651044011366

# %% [markdown]
# ## Use of Statistics Library

# %%
import statistics 
statistics.variance(data_copy)
# Out:
# 1283.4772727272727

# %%
statistics.pvariance(data)
# Out:
# 226.2314049586777

# %%
import math
math.sqrt(statistics.variance(data))
# Out:
# 15.775124261144363

# %% [markdown]
# ## Correlation and Covariance

# %%
df=sns.load_dataset('tips')

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x=df['tip'],y=df['size'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='size'>

# %%
sns.scatterplot(x=df['tip'],y=df['total_bill'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
df.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %% [markdown]
# ## Probability Distribution Function

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(data2['SepalLengthCm'],kde=True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %% [markdown]
# ## {Normal Distribution}

# %%
sns.histplot(data2['SepalWidthCm'],kde=True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data2['PetalLengthCm'],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
data_copy.append(289)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150, 210, 289]

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data_copy2.pop()
# Out:
# 75

# %%
data_copy2[0]=-10

# %%
data_copy2[1]=-75

# %%
data_copy2
# Out:
# [-10, -75, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data2['PetalWidthCm'],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Count'>

# %%
np.random.normal(0.5,0.2,1000)
# Out:
# array([ 0.27676709,  0.43743599,  0.28611127,  0.25725637,  0.72343488,
#         0.41074855,  0.33492874,  0.20921637,  0.42872218,  0.6932268 ,
#         0.69424959,  0.73261865,  0.87478054,  0.92977388,  0.44248338,
#         0.28747954,  0.67482241,  0.42345981,  0.39310386, -0.060001  ,
#         0.80767279,  0.40175647,  0.27499035,  0.24721895,  0.51750172,

# Out:
# <AxesSubplot:ylabel='Count'>

# %%
mu,sigma=3.0,1.0
p=np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(p,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(np.log(p),kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

# %%
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(data)

# %%
plot_data(s)

# %%
plot_data(p)

# %%
plot_data(np.log(p))

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ------------------------------------- 324.4/324.4 kB 10.1 MB/s eta 0:00:00
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.1.0-py2.py3-none-any.whl (344 kB)
#      ------------------------------------- 344.9/344.9 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (3.5.2)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ---------------------------------------- 102.7/102.7 kB ? eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.4.4)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-win_amd64.whl (663 kB)
#      ------------------------------------- 663.5/663.5 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (4.64.1)
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.6-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.11.3)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.21.5)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\devas\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ------------------------------------- 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\devas\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.2.0)
# Requirement already satisfied: PyWavelets in c:\users\devas\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.3.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.4 in c:\users\devas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.4)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\devas\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\devas\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\devas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\devas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\devas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\devas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\devas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\devas\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devas\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\devas\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\devas\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\devas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\devas\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.11)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\devas\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\devas\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.5)
# Requirement already satisfied: six in c:\users\devas\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=6fec2f2101bab70e189341cbe38c05fcea3fec0341b1250897e7113d2245f6d9
#   Stored in directory: c:\users\devas\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, pydantic, multimethod, imagehash, visions, phik, ydata-profiling, pandas-profiling
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 pandas-profiling-3.6.6 phik-0.12.3 pydantic-1.10.6 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import ydata_profiling

# %%
profile=data3.profile_report()

# %%
profile.to_file(output_file="output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
