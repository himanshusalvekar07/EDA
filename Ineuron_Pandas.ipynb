# %%
import pandas as pd

# %%
data=pd.read_csv("addresses.csv")

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(6)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US

# %%
data.tail(7)
# Out:
#     id  location_id                   address_1  address_2  \
# 14  15           15        1500 Valencia Street        NaN
# 15  16           16         1161 South Bernardo        NaN
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 14        San Francisco             CA       94110      US
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data[['city','location_id']]
# Out:
#                    city  location_id
# 0          Redwood City            1
# 1             San Mateo            2
# 2             San Mateo            3
# 3             San Mateo            4
# 4             San Mateo            5
# 5            Menlo Park            6
# 6            Menlo Park            7
# 7            Menlo Park            8
# 8          Redwood City            9
# 9          Redwood City           10
# 10         Redwood City           11
# 11         Redwood City           12
# 12         Redwood City           13
# 13         Redwood City           14
# 14        San Francisco           15
# 15            Sunnyvale           16
# 16  South San Francisco           17
# 17         Redwood City           18
# 18            San Mateo           19
# 19              Belmont           21
# 20        San Francisco           22

# %%
type(data['state_province'])
# Out:
# pandas.core.series.Series

# %%
pd.read_excel('airline1.xls')
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline1.xls",sheet_name="Sheet2")
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574
# 5  1953  2.731  0.322  0.3593  1.926  0.711
# 6  1954  3.025  0.335  0.4025  1.964  0.776
# 7  1955  3.562  0.350  0.3961  2.116  0.827
# 8  1956  3.979  0.361  0.3822  2.435  0.800

# %%
data1=pd.read_excel("airline1.xls",sheet_name="Sheet3",header=None,names=['a','b','c','d','e','f'])

# %%
type(pd.read_excel("airline1.xls",sheet_name="Sheet3",header=None))
# Out:
# pandas.core.frame.DataFrame

# %%
data1
# Out:
#        a       b      c       d      e      f
# 0   1960   5.554  0.441  0.3193  3.089  1.481
# 1   1961   5.465  0.460  0.3079  3.122  1.736
# 2   1962   5.825  0.485  0.3783  3.184  1.926
# 3   1963   6.876  0.506  0.4180  3.263  2.041
# 4   1964   7.823  0.538  0.5163  3.412  1.997
# 5   1965   9.120  0.564  0.5879  3.623  2.257
# 6   1966  10.512  0.586  0.5369  4.074  2.742
# 7   1967  13.020  0.622  0.4443  4.710  3.564
# 8   1968  15.261  0.666  0.3052  5.217  4.767
# 9   1969  16.313  0.731  0.2332  5.569  6.511
# 10  1970  16.002  0.831  0.1883  5.495  7.627
# 11  1971  15.876  0.906  0.2023  5.334  8.673
# 12  1972  16.662  1.000  0.2506  5.345  8.331
# 13  1973  17.014  1.056  0.2668  5.662  8.557
# 14  1974  19.305  1.131  0.2664  5.729  9.508
# 15  1975  18.721  1.247  0.2301  5.722  9.062

# %%
data1.to_csv('test1.csv')

# %%
data1.to_csv('test2.xlsx',index=False)

# %%
tuple(data1.columns)
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
data1[['b','c']]
# Out:
#          b      c
# 0    5.554  0.441
# 1    5.465  0.460
# 2    5.825  0.485
# 3    6.876  0.506
# 4    7.823  0.538
# 5    9.120  0.564
# 6   10.512  0.586
# 7   13.020  0.622
# 8   15.261  0.666
# 9   16.313  0.731
# 10  16.002  0.831
# 11  15.876  0.906
# 12  16.662  1.000
# 13  17.014  1.056
# 14  19.305  1.131
# 15  18.721  1.247

# %%
data1.to_csv('test3.xlsx')

# %%
data3=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data2=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
len(data2)
# Out:
# 1

# %%
data2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
data2[0].to_csv("Players.csv")

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data3.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data3[["Name","Sex","Ticket"]].describe()
# Out:
#                                         Name   Sex    Ticket
# count                                    891   891       891
# unique                                   891     2       681
# top     Andersson, Miss. Ingeborg Constanzia  male  CA. 2343
# freq                                       1   577         7

# %%
data3.dtypes[data3.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# ## Showcasing columns with 'Obj' DataType

# %%
data3[data3.dtypes[data3.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data3.dtypes[data3.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data3.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data3.dtypes[data3.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data3[data3["Survived"]==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data3[data3["Survived"]==0][data3["Sex"]=="male"]
# Out:
# <ipython-input-22-aae9c6a673f4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data3[data3["Survived"]==0][data3["Sex"]=="male"]
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# ...

# %% [markdown]
# ## Showcasing Males/Females who have survived .

# %%
data3[(data3["Survived"]==0) & (data3["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data3[(data3["Survived"]==0) & (data3["Sex"]=="male")].value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                        Sex   Age   SibSp  Parch  Ticket         Fare      Cabin        Embarked
# 7            0         1       McCarthy, Mr. Timothy J                     male  54.0  0      0      17463          51.8625   E46          S           1
# 660          0         1       Newell, Mr. Arthur Webster                  male  58.0  0      2      35273          113.2750  D48          C           1
# 453          0         1       Foreman, Mr. Benjamin Laventall             male  30.0  0      0      113051         27.7500   C111         C           1
# 457          0         1       Millet, Mr. Francis Davis                   male  65.0  0      0      13509          26.5500   E38          S           1
# 463          0         1       Gee, Mr. Arthur H                           male  47.0  0      0      111320         38.5000   E63          S           1
# ...

# %%
len(data3[(data3["Survived"]==0) & (data3["Sex"]=="male")])
# Out:
# 468

# %%
len(data3[(data3["Survived"]==0) & (data3["Sex"]=="female")])
# Out:
# 81

# %%
len(data3[data3["Sex"]=="female"])
# Out:
# 314

# %%
len(data3[data3["Sex"]=="male"])
# Out:
# 577

# %%
len(data3[(data3["Survived"]==1) & (data3["Sex"]=="male")])
# Out:
# 109

# %%
len(data3[(data3["Survived"]==1) & (data3["Sex"]=="female")])
# Out:
# 233

# %%
def max_num(l):
    
    max=0
    for i in l:
        if i>max:
            max=i
    print(f"Maximum in the given list's: {max}!")

# %%
max_num([12,1,2,3,4,13,5,6,7])
# Out:
# Maximum in the given list's: 13!

# %%
max(data3["Fare"])
# Out:
# 512.3292

# %%
data3[data3['Fare']==max(data3['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
data3['Fare']==max(data3['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %% [markdown]
# ## People Paying the max Fare.

# %%
data3[data3['Fare']==max(data3['Fare'])][["Name"]]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %% [markdown]
# People having a cabin.

# %% [markdown]
# ## People With Cabins

# %%
data3[data3['Cabin'].isnull()==False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Introducing a new column in the dataset.

# %%
data3['new_col']='Himanshu'

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## COLUMN DUPLiCATiON

# %%
data3['New_Name']=data3['Name']

# %%
data3['age_Pclass'] = data3['Pclass'] + data3['Age']

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# axis0=Row
# axix1=Column

# %% [markdown]
# ## Column Dropping

# %%
data3.drop('new_col',axis=1,inplace=True)

# %%
data3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
data3.drop('New_Name',axis=1,inplace=True)

# %%
data3.drop('age_Pclass',axis=1,inplace=True)

# %% [markdown]
# ## Row-Related Ops

# %%
#data3.drop(0,inplace=True)

# %%
data3.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data3.iloc[890]
# Out:
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object

# %%
data3.iloc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
data3[['Survived','Pclass']].loc[100:106]
# Out:
#      Survived  Pclass
# 100         0       3
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
data3[['Survived']].iloc[100:106]
# Out:
#      Survived
# 100         0
# 101         0
# 102         0
# 103         0
# 104         0
# 105         0

# %%
data3[['Fare','Cabin','Embarked']].iloc[4:5]
# Out:
#    Fare Cabin Embarked
# 4  8.05   NaN        S

# %%
data3.iloc[: ,  [0,2]]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data3.iloc[4:5 ,  [9,10,11]]
# Out:
#    Fare Cabin Embarked
# 4  8.05   NaN        S

# %%
data3.loc[:,['PassengerId','Pclass']]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data3.loc[4:5 ,  ['Cabin','Fare','Embarked']]
# Out:
#   Cabin    Fare Embarked
# 4   NaN  8.0500        S
# 5   NaN  8.4583        Q

# %%
data3.loc[[3,5],['PassengerId','Survived','Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data3.iloc[[3,5],[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
data3[(data3['Age']>35) & (data3['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data3.loc[4:6 , ['Name','Parch']]
# Out:
#                        Name  Parch
# 4  Allen, Mr. William Henry      0
# 5          Moran, Mr. James      0
# 6   McCarthy, Mr. Timothy J      0

# %%
data4=data3.iloc[1:10,[2,3,4,5,9,10]]

# %%
data4
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 6       1                            McCarthy, Mr. Timothy J    male  54.0
# 7       3                     Palsson, Master. Gosta Leonard    male   2.0
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN
# 6  51.8625   E46
# 7  21.0750   NaN
# 8  11.1333   NaN
# 9  30.0708   NaN

# %%
data4.set_index('Name',inplace=True)

# %%
data4
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Palsson, Master. Gosta Leonard                           3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# ...

# %%
type(data4)
# Out:
# pandas.core.frame.DataFrame

# %%
data4.dropna(axis=1)
# Out:
#                                                     Pclass     Sex     Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  71.2833
# Heikkinen, Miss. Laina                                   3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  53.1000
# Allen, Mr. William Henry                                 3    male   8.0500
# Moran, Mr. James                                         3    male   8.4583
# McCarthy, Mr. Timothy J                                  1    male  51.8625
# Palsson, Master. Gosta Leonard                           3    male  21.0750
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  11.1333
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  30.0708

# %%
data4
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Palsson, Master. Gosta Leonard                           3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# ...

# %%
data4.dropna(axis=1,thresh=7)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Palsson, Master. Gosta Leonard                           3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# ...

# %%
data4
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Palsson, Master. Gosta Leonard                           3    male   2.0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# ...

# %%
data4.fillna(data4['Age'].mean())
# Out:
#                                                     Pclass     Sex     Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.000
# Heikkinen, Miss. Laina                                   3  female  26.000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.000
# Allen, Mr. William Henry                                 3    male  35.000
# Moran, Mr. James                                         3    male  28.875
# McCarthy, Mr. Timothy J                                  1    male  54.000
# Palsson, Master. Gosta Leonard                           3    male   2.000
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3  female  27.000
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.000
#
#                                                        Fare   Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833     C85
# Heikkinen, Miss. Laina                               7.9250  28.875
# ...

# %%
data4.groupby('Sex').sum()
# Out:
#         Pclass    Age      Fare
# Sex
# female      10  140.0  173.5124
# male        10   91.0   89.4458

# %%
data2=data3.iloc[0:4,0:5]

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female

# %%
pd.concat([data4,data2])
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 6       1                            McCarthy, Mr. Timothy J    male  54.0
# 7       3                     Palsson, Master. Gosta Leonard    male   2.0
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 0       3                            Braund, Mr. Owen Harris    male   NaN
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   NaN
# ...

# %%
data2['new']=data2['Pclass'].apply(lambda x:x/3)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex       new
# 0                            Braund, Mr. Owen Harris    male  1.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.333333
# 2                             Heikkinen, Miss. Laina  female  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.333333

# %%
data2['name_len']=data2['Name'].apply(len)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex       new  \
# 0                            Braund, Mr. Owen Harris    male  1.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.333333
# 2                             Heikkinen, Miss. Laina  female  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.333333
#
#    name_len
# 0        23
# 1        51
# 2        22
# 3        44

# %%
data2['Passgid_filter']=data2['PassengerId'].apply(func0)

# %%
import math
def func0(x):
    if x<3:
        return x
    else:
        return math.log10(x)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex       new  \
# 0                            Braund, Mr. Owen Harris    male  1.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.333333
# 2                             Heikkinen, Miss. Laina  female  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.333333
#
#    name_len  Passgid_filter
# 0        23        1.000000
# 1        51        2.000000
# 2        22        0.477121
# 3        44        0.602060

# %%
def func1(x):
    i=1
    q=0
    if x == 'female':
        return i
    else:
        return q

# %%
data2['Sex']==data2['Sex'].apply(func1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: Sex, dtype: bool

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex       new  \
# 0                            Braund, Mr. Owen Harris    male  1.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.333333
# 2                             Heikkinen, Miss. Laina  female  1.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.333333
#
#    name_len  Passgid_filter
# 0        23        1.000000
# 1        51        2.000000
# 2        22        0.477121
# 3        44        0.602060

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def func2(x):
    if x<101:
        return "A"
    if x>=101 and x<200:
        return "B"
    if x>200:
        return "C"

# %%
data3['Fare_group']=data3['Fare'].apply(func2)

# %%
data3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data3[data3["Fare_group"]=="A"])
# Out:
# 838

# %%
len(data3[(data3['Pclass']==2) & (data3['Survived']==1)])
# Out:
# 87

# %%
data3[['Cabin']].isnull()==False
# Out:
# <>:1: SyntaxWarning: 'bool' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'bool' object is not subscriptable; perhaps you missed a comma?
# <ipython-input-50-d543d6b702da>:1: SyntaxWarning: 'bool' object is not subscriptable; perhaps you missed a comma?
#   data3[['Cabin']].isnull()==False[["Name"]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-d543d6b702da> in <module>
# ----> 1 data3[['Cabin']].isnull()==False[["Name"]]
#
# TypeError: 'bool' object is not subscriptable

# %%
len(data3[data3['Cabin'].isnull()==False])
# Out:
# 204

# %%
data3[(data3["Survived"]==0) & (data3["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked Fare_group
# ...

# %%
data3[(data3["Survived"]==0) & (data3["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked Fare_group
# ...

# %%
data3[(data3["Fare"]==max(data3["Fare"])) & (data3["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
# 737          738         1       1              Lesurer, Mr. Gustave J  male
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked Fare_group
# 679  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C          C
# 737  35.0      0      0  PC 17755  512.3292         B101        C          C

# %%
len(data3[(data3["Fare"]==max(data3["Fare"])) & (data3["Sex"]=="male")])
# Out:
# 2

# %%
data3[(data3["Fare"]==max(data3["Fare"])) & (data3["Sex"]=="female")]
# Out:
#      PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 258          259         1       1  Ward, Miss. Anna  female  35.0      0
#
#      Parch    Ticket      Fare Cabin Embarked Fare_group
# 258      0  PC 17755  512.3292   NaN        C          C

# %%
len(data3[data3["Cabin"].isnull()==False])
# Out:
# 204
